# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-eb363695-b50a-447a-b637-9a48c6aa4b7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb363695-b50a-447a-b637-9a48c6aa4b7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Iris.csv')
display(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/kaggle dataset/NIRF Ranking 2025.csv')
df.head()
# Out:
#   Institute ID                         Institute Name    TLR    RPC     GO  \
# 0  IR-O-U-0456  Indian Institute of Technology Madras  90.58  88.02  87.01
# 1  IR-O-U-0220            Indian Institute of Science  86.47  88.16  83.69
# 2  IR-O-U-0306  Indian Institute of Technology Bombay  83.79  83.05  86.04
# 3  IR-O-I-1074   Indian Institute of Technology Delhi  80.52  86.67  74.71
# 4  IR-O-I-1075  Indian Institute of Technology Kanpur  86.36  72.12  82.01
#
#       OI  PERCEPTION       City          State  Score  Rank
# 0  63.34      100.00    Chennai     Tamil Nadu  87.31     1
# 1  60.29       98.41  Bengaluru      Karnataka  85.00     2
# 2  60.13       83.35     Mumbai    Maharashtra  81.62     3
# 3  63.54       92.23  New Delhi          Delhi  80.67     4
# 4  60.38       72.56     Kanpur  Uttar Pradesh  77.25     5

# %%
pip install kagglehub[pandas-datasets]

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "abidhussai512/gdp-and-consumption-per-capita",
    "Gross domestic product (GDP) and main components per capita (nama_10_pc).csv"
)

print(df.head())
# Out:
# ...
# 100%|██████████| 853k/853k [00:00<00:00, 78.0MB/s]
#   frq         unit na_itm   go   1995   1996   1997   1998   1999   2000  ...  \
# 0   A  CLV10_UR_HA    1GQ   AL   1370   1480   1310   1430   1620   1750  ...
# 1   A  CLV10_UR_HA    1GQ   AT  27450  28020  28590  29560  30610  31510  ...
# 2   A  CLV10_UR_HA    1GQ  NaN  26270  26560  27500  27980  28910  29910  ...
# 3   A  CLV10_UR_HA    1GQ    G   3240   3430   2960   3090   2850   2990  ...
# 4   A  CLV10_UR_HA    1GQ   CH  48350  48400  49270  50470  51050  52630  ...
#
#       2015     2016   2017   2018   2019   2020   2021   2022   2023   2024
# 0   3480.0   3620.0   3750   3890   3990   3880   4270   4530
# 1  35930.0  36230.0  36820  37550  38040  35480  37080  38620  37990  37550
# 2  34090.0  34320.0  34700  35190  35850  33990  35960  37090  37400  37580
# 3   5850.0   6110.0   6360   6600   6950   6800   7380   7730   7880   8160
# 4  60400.0  60900.0  61200  62780  63030  61140  64440  66160  65710  65880
#
# ...

# %%
import kagglehub
path = kagglehub.dataset_download("timoboz/data-science-cheat-sheets")
# Out:
# ...
# 100%|██████████| 596M/596M [00:08<00:00, 70.8MB/s]
# Extracting files...

# %%
import os

base_path = "/root/.cache/kagglehub/datasets/timoboz/data-science-cheat-sheets"
os.listdir(base_path)
# Out:
# ['1.complete', 'versions']

# %%
versions_path = base_path + "/versions"
os.listdir(versions_path)
# Out:
# ['1']

# %%
dataset_path = versions_path + "/1"
os.listdir(dataset_path)
# Out:
# ['Python',
#  'Artificial Intelligence',
#  'Probability',
#  'CBAP.pdf',
#  'Numpy',
#  'DevOps',
#  'Interview Questions',
#  'Git',
#  'Images',
#  'Ordinary Differential Equations',
#  'Docker and Kubernetes',
#  'Pandas',
#  'R Cheat Sheet',
#  'Data Warehouse',
#  'Data Mining',
#  'Matlab',
#  'Statistics',
#  'Linux',
#  'Scala',
#  'Mathematics',
#  'NLP',
#  'README.md',
#  'Data Science',
#  'Big Data',
#  'Deep Learning',
#  'Data Visualization',
#  'Algorithms',
#  'Data Engineering',
#  'Excel',
#  'Machine Learning',
#  'SQL']
